# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_hdf('../../../data/conductance_prof/all_data.hdf')
df = df.reset_index()[['light_power', 'radius [um]','angle [rad]','AP_count','total_int_g','total_peak_g','max_int_sec_g']]
df
# Out:
#       light_power  radius [um]  angle [rad]  AP_count   total_int_g  \
# 0         0.00003            0     0.000000         0  2.506613e-06
# 1         0.00003            0     0.392699         0  2.506613e-06
# 2         0.00003            0     0.785398         0  2.506613e-06
# 3         0.00003            0     1.178097         0  2.506613e-06
# 4         0.00003            0     1.570796         0  2.506613e-06
# ...           ...          ...          ...       ...           ...
# 3195      0.02000          975     4.319690         0  1.618664e-09
# 3196      0.02000          975     4.712389         0  1.616577e-09
# 3197      0.02000          975     5.105088         0  1.606427e-09
# 3198      0.02000          975     5.497787         0  1.596879e-09
# 3199      0.02000          975     5.890486         0  1.592404e-09
#
#       total_peak_g  max_int_sec_g
# 0     1.287014e-09   5.893425e-08
# 1     1.287014e-09   5.893425e-08
# 2     1.287014e-09   5.893425e-08
# 3     1.287014e-09   5.893425e-08
# 4     1.287014e-09   5.893425e-08
# ...            ...            ...
# 3195  8.326221e-13   6.545093e-11
# 3196  8.315486e-13   6.545094e-11
# 3197  8.263257e-13   6.545102e-11
# 3198  8.214130e-13   6.545110e-11
# 3199  8.191474e-13   6.544781e-11
#
# [3200 rows x 7 columns]

# %%
df['norm_total_int_g'] = df.groupby(['light_power'])['total_int_g'].apply(lambda x: x/x.max())
df['norm_total_peak_g'] = df.groupby(['light_power'])['total_peak_g'].apply(lambda x: x/x.max())
df['norm_max_int_sec_g'] = df.groupby(['light_power'])['max_int_sec_g'].apply(lambda x: x/x.max())
df = df.set_index(['light_power', 'radius [um]', 'angle [rad]'])

# %%
df
# Out:
#                                      AP_count   total_int_g  total_peak_g  \
# light_power radius [um] angle [rad]
# 0.00003     0           0.000000            0  2.506613e-06  1.287014e-09
#                         0.392699            0  2.506613e-06  1.287014e-09
#                         0.785398            0  2.506613e-06  1.287014e-09
#                         1.178097            0  2.506613e-06  1.287014e-09
#                         1.570796            0  2.506613e-06  1.287014e-09
# ...                                       ...           ...           ...
# 0.02000     975         4.319690            0  1.618664e-09  8.326221e-13
#                         4.712389            0  1.616577e-09  8.315486e-13
#                         5.105088            0  1.606427e-09  8.263257e-13
#                         5.497787            0  1.596879e-09  8.214130e-13
#                         5.890486            0  1.592404e-09  8.191474e-13
#
#                                      max_int_sec_g  norm_total_int_g  \
# light_power radius [um] angle [rad]
# 0.00003     0           0.000000      5.893425e-08          0.891552
#                         0.392699      5.893425e-08          0.891552
#                         0.785398      5.893425e-08          0.891552
#                         1.178097      5.893425e-08          0.891552
#                         1.570796      5.893425e-08          0.891552
# ...                                            ...               ...
# 0.02000     975         4.319690      6.545093e-11          0.000007
#                         4.712389      6.545094e-11          0.000007
#                         5.105088      6.545102e-11          0.000007
#                         5.497787      6.545110e-11          0.000007
#                         5.890486      6.544781e-11          0.000007
#
#                                      norm_total_peak_g  norm_max_int_sec_g
# light_power radius [um] angle [rad]
# 0.00003     0           0.000000              0.888858            0.670552
#                         0.392699              0.888858            0.670552
#                         0.785398              0.888858            0.670552
#                         1.178097              0.888858            0.670552
#                         1.570796              0.888858            0.670552
# ...                                                ...                 ...
# 0.02000     975         4.319690              0.000004            0.000028
#                         4.712389              0.000004            0.000028
#                         5.105088              0.000004            0.000028
#                         5.497787              0.000004            0.000028
#                         5.890486              0.000004            0.000028
#
# [3200 rows x 7 columns]

# %%
pd.DataFrame(df.loc[5e-4].norm_total_int_g - df.loc[5e-5].norm_total_int_g).reset_index()
# Out:
#      radius [um]  angle [rad]  norm_total_int_g
# 0              0     0.000000      7.662237e-02
# 1              0     0.392699      7.662237e-02
# 2              0     0.785398      7.662237e-02
# 3              0     1.178097      7.662237e-02
# 4              0     1.570796      7.662237e-02
# ..           ...          ...               ...
# 635          975     4.319690      4.275873e-07
# 636          975     4.712389      4.270361e-07
# 637          975     5.105088      4.243549e-07
# 638          975     5.497787      4.218329e-07
# 639          975     5.890486      4.206723e-07
#
# [640 rows x 3 columns]

# %%
df = df.loc[:,:300,:]

# %%
import matplotlib.colors
from neurostim.polarmaps import simple_polar_map
import matplotlib as mpl
import matplotlib.pyplot as plt
import copy
lps = df.reset_index().light_power.unique()
lps = [5e-5,5e-4,2e-2]

fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
ax, mappable = simple_polar_map(
        data=pd.DataFrame(df.loc[5e-4].norm_total_int_g - df.loc[5e-5].norm_total_int_g).reset_index(),
        plot_col='norm_total_int_g',
        cmap=copy.copy(mpl.cm.get_cmap("coolwarm")),
        norm = matplotlib.colors.DivergingNorm(
            vmin=-0.15,
            vcenter=0,
            vmax=0.15),
        ax=ax,
        vmin=None,
        vmax=None)
plt.colorbar(mappable)
plt.title('5e-4 - 5e-5')
plt.show()
# fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
# ax, mappable = simple_polar_map(
#         data=pd.DataFrame(df.loc[5e-4].total_int_g - df.loc[5e-5].total_int_g).reset_index(),
#         plot_col='total_int_g',
#         cmap=copy.copy(mpl.cm.get_cmap("coolwarm")),
#         ax=ax,
#         vmin=None,
#         vmax=None)
# plt.colorbar(mappable)
# plt.title(str(lp))
# plt.show()

for lp in lps:
    fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
    ax, mappable = simple_polar_map(
            data=df.loc[lp].reset_index(),
            plot_col='AP_count',
            cmap=copy.copy(mpl.cm.get_cmap("Reds")),
            ax=ax,
            vmin=0,
            vmax=25)
    #plt.colorbar(mappable)
    plt.title(str(lp))
    plt.savefig('plots/tmp_fr_'+str(lp)+'.png', dpi=300)
    plt.show()
# fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
# ax, mappable = simple_polar_map(
#         data=pd.DataFrame(df.loc[2e-2].norm_total_int_g - df.loc[5e-4].norm_total_int_g).reset_index(),
#         plot_col='norm_total_int_g',
#         cmap=copy.copy(mpl.cm.get_cmap("coolwarm")),
#         norm = matplotlib.colors.DivergingNorm(
#                 vmin=-0.5,
#                 vcenter=0,
#                 vmax=0.5),
#         ax=ax,
#         vmin=None,
#         vmax=None)
# plt.colorbar(mappable)
# plt.show()
# for lp in lps:
#     fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
#     ax, mappable = simple_polar_map(
#             data=df.loc[lp].reset_index(),
#             plot_col='norm_total_int_g',
#             cmap=copy.copy(mpl.cm.get_cmap("jet")),
#             ax=ax,
#             vmin=0,
#             vmax=1)
#     #plt.colorbar(mappable)
#     plt.title(str(lp))
#     plt.savefig('plots/tmp_cond_'+str(lp)+'.png', dpi=300)
#     plt.show()
# for lp in lps:
#     fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
#     ax, mappable = simple_polar_map(
#             data=df.loc[lp].reset_index(),
#             plot_col='norm_total_peak_g',
#             cmap=copy.copy(mpl.cm.get_cmap("jet")),
#             ax=ax,
#             vmin=0,
#             vmax=1)
#     #plt.colorbar(mappable)
#     plt.title(str(lp))
#     plt.savefig('plots/tmp_peak_cond_'+str(lp)+'.png', dpi=300)
#     plt.show()

for lp in lps:
    fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
    ax, mappable = simple_polar_map(
            data=df.loc[lp].reset_index(),
            plot_col='norm_max_int_sec_g',
            cmap=copy.copy(mpl.cm.get_cmap("jet")),
            ax=ax,
            vmin=0,
            vmax=1)
    #plt.colorbar(mappable)
    plt.title(str(lp))
    plt.savefig('plots/tmp_max_cond_'+str(lp)+'.png', dpi=300)
    plt.show()
# Out:
# /home/david/Software/miniconda3/envs/mioos/lib/python3.6/site-packages/ipykernel_launcher.py:17: MatplotlibDeprecationWarning:
# The DivergingNorm class was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use TwoSlopeNorm instead.
